# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("general_data.csv")
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
dataset1
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# min              0.000000          11.000000           0.000000
# ...

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].median()
dataset1
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
dataset1
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
dataset1
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
dataset1
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
dataset1
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %% [markdown]
#   Inference from the analysis:
# -All the above variables show positive skewness; while Age & Mean_distance_from_home are leptokurtic and all other variables are platykurtic.
# -The Mean_Monthly_Income’s IQR is at 54K suggesting company wide attrition across all income bands
# -Mean age forms a near normal distribution with 13 years of IQR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("general_data.csv")
from sklearn import preprocessing
from scipy.stats import pearsonr
dataset["Attrition"].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)
dataset.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.Attrition.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
plt.scatter(dataset.Attrition,dataset.Age)

# %%
plt.scatter(dataset.Attrition,dataset.TotalWorkingYears)

# %%
plt.scatter(dataset.Attrition,dataset.MonthlyIncome)

# %%
plt.scatter(dataset.Attrition,dataset.YearsAtCompany)

# %% [markdown]
# There is no regression found while plotting Age, MonthlyIncome, TotalWorkingYears, YearsAtCompany on a scatter plot

# %%
plt.boxplot(dataset.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc7b4408>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xc7b4f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xc7abb08>],
#  'medians': [<matplotlib.lines.Line2D at 0xc7b7a08>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc7b7f48>],
#  'means': []}

# %% [markdown]
# Age is normally distributed with no outliers.

# %%
plt.boxplot(dataset.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc810448>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xc810f48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xc80ab88>],
#  'medians': [<matplotlib.lines.Line2D at 0xc816bc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc816c88>],
#  'means': []}

# %% [markdown]
# Monthly Income is Right skewed with several outliers.

# %%
plt.boxplot(dataset.YearsAtCompany)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xc8e3648>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xc8e3c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xc8dcd48>],
#  'medians': [<matplotlib.lines.Line2D at 0xc8eac48>],
#  'fliers': [<matplotlib.lines.Line2D at 0xc8ead08>],
#  'means': []}

# %% [markdown]
# Years at company is  Right hand side Skewed with several outliers observed.

# %% [markdown]
# **Statistical Test**

# %% [markdown]
# **1. Using Mann whitney test for Attrition and DistanceFromHome )**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("general_data.csv")
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("general_data.csv")
dataset.head()
from sklearn import preprocessing
from scipy.stats import pearsonr
dataset["Attrition"].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)
dataset.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
from scipy.stats import mannwhitneyu
dataset1=dataset[dataset["Attrition"]==0]
dataset1.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
# 5   46          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
# 5                 8          3  Life Sciences              1           6
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
dataset2=dataset[dataset["Attrition"]==1]
dataset2.head(5)
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 1    31          1  Travel_Frequently  Research & Development
# 6    28          1      Travel_Rarely  Research & Development
# 13   47          1         Non-Travel  Research & Development
# 28   44          1  Travel_Frequently  Research & Development
# 30   26          1      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset_data_list=['1']
dataset_sv=dataset[dataset.Attrition.isin(dataset_data_list)]
dataset_sv.Attrition.unique()
dataset_sv.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 1    31          1  Travel_Frequently  Research & Development
# 6    28          1      Travel_Rarely  Research & Development
# 13   47          1         Non-Travel  Research & Development
# 28   44          1  Travel_Frequently  Research & Development
# 30   26          1      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset_data_list=['0']
dataset_sv1=dataset[dataset.Attrition.isin(dataset_data_list)]
dataset_sv1.Attrition.unique()
dataset_sv1.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
# 5   46          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
# 5                 8          3  Life Sciences              1           6
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
stats,p=mannwhitneyu(dataset_sv.DistanceFromHome,dataset_sv1.DistanceFromHome)
print(stats,p)
# Out:
# 1312110.0 0.4629185205822659

# %% [markdown]
# As the P value of 0.4629185205822659 is > 0.05, the H0 is accepted and Ha is rejected.
# H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition (N)
# Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)

# %% [markdown]
# **2.Using Mann whitney test for Attrition and MonthlyIncome**

# %%
stats,p=mannwhitneyu(dataset_sv.MonthlyIncome,dataset_sv1.MonthlyIncome)
print(stats,p)
# Out:
# 1264900.5 0.053577283839938566

# %% [markdown]
# As the P value of 0.053577283839938566 is > 0.05, the H0 is accepted and Ha is accepted.
# H0: There is no significant differences in the MonthlyIncome between attrition (Y) and attirition (N)
# Ha: There is significant differences in the MonthlyIncome between attrition (Y) and attirition (N)

# %% [markdown]
# **3.Using Mann whitney test for Attrition and TotalWorkingYears**

# %%
stats,p=mannwhitneyu(dataset_sv.TotalWorkingYears,dataset_sv1.TotalWorkingYears)
print(stats,p)
# Out:
# 909954.0 2.8897554531400447e-39

# %% [markdown]
# As the P value is 2.894653260702919e-39, which is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition (N)
# Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)

# %% [markdown]
# **4.Using Mann whitney test for Attrition and YearsAtCompany**

# %%
stats,p=mannwhitneyu(dataset_sv.YearsAtCompany,dataset_sv1.YearsAtCompany)
print(stats,p)
# Out:
# 923238.0 6.047598261692858e-37

# %% [markdown]
# As the P value is 6.047598261693028e-37, which is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the YearsAtCompany between attrition (Y) and attirition (N)
# Ha: There is significant differences in the YearsAtCompany between attrition (Y) and attirition (N)

# %% [markdown]
# **Statistical test- Seperate t test**

# %% [markdown]
# **Attrition and Distance From Home**

# %%
from scipy.stats import ttest_ind
a1=dataset[dataset["Attrition"]==0]
a1.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
# 5   46          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
# 5                 8          3  Life Sciences              1           6
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
a2=dataset[dataset["Attrition"]==1]
a2.head(5)
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 1    31          1  Travel_Frequently  Research & Development
# 6    28          1      Travel_Rarely  Research & Development
# 13   47          1         Non-Travel  Research & Development
# 28   44          1  Travel_Frequently  Research & Development
# 30   26          1      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
from scipy.stats import ttest_ind

# %%
stats,p=ttest_ind(a1.DistanceFromHome,a2.DistanceFromHome)
print(stats,p)
# Out:
# 0.6460416038042738 0.518286042805572

# %%
As the P value is 0.518286042805572, which is > than 0.05, the H0 is accepted and ha is rejected.
H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition (N)
Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)

# %% [markdown]
# **Attrition and  MonthlyIncome**

# %%
stats,p=ttest_ind(a1.MonthlyIncome,a2.MonthlyIncome)
print(stats,p)
# Out:
# 2.0708863763619316 0.03842748490605113

# %% [markdown]
# As the P value is 0.03842748490605113, which is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Monthly Income between attrition (Y) and attirition (N)
# Ha: There is significant differences in the Monthly Income between attrition (Y) and attirition (N)

# %% [markdown]
# **Attrition and YearsAtCompany**

# %%
stats,p=ttest_ind(a1.YearsAtCompany,a2.YearsAtCompany)
print(stats,p)
# Out:
# 9.004357011787226 3.163883122491456e-19

# %% [markdown]
# As the P value is 3.163883122491456e-19, which is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Years At Company between attrition (Y) and attirition (N)
# Ha: There is significant differences in the Years At Company between attrition (Y) and attirition (N)

# %% [markdown]
# **Attrition and YearsWithCurrentManager**

# %%
stats,p=ttest_ind(a1.YearsWithCurrManager,a2.YearsWithCurrManager)
print(stats,p)
# Out:
# 10.499379408703438 1.7339322652918153e-25

# %% [markdown]
# As the P value is 1.7339322652918153e-25, which is < than 0.05, the H0 is rejected and ha is accepted.
# H0: There is no significant differences in the Years With Current Manager between attrition (Y) and attirition (N)
# Ha: There is significant differences in the Years With Current Manager between attrition (Y) and attirition (N)

# %% [markdown]
# **Correlation Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("general_data.csv")
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
from sklearn import preprocessing
from scipy.stats import pearsonr
dataset["Attrition"].replace(to_replace=("No","Yes"),value=(0,1),inplace=True)
dataset.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
dataset.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
dataset["Department"].replace(to_replace=("Sales","Research & Development","Human Resources"),value=(0,1,2),inplace=True)
dataset.head(5)
# Out:
#    Age  Attrition     BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0      Travel_Rarely           0                 6          2
# 1   31          1  Travel_Frequently           1                10          1
# 2   32          0  Travel_Frequently           1                17          4
# 3   38          0         Non-Travel           1                 2          5
# 4   32          0      Travel_Rarely           1                10          1
#
#   EducationField  EmployeeCount  EmployeeID  Gender  ...  NumCompaniesWorked  \
# 0  Life Sciences              1           1       0  ...                 1.0
# 1  Life Sciences              1           2       0  ...                 0.0
# 2          Other              1           3       1  ...                 1.0
# 3  Life Sciences              1           4       1  ...                 3.0
# 4        Medical              1           5       1  ...                 4.0
#
# ...

# %% [markdown]
# **Correlation between Attrition and Department. H0 = There is no significant correlation between Attrition and DDepartment Ha = There is significant correlation between Attrition and Department**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.Department)
print(stats,p)
# Out:
# 0.04820581991833996 0.0013638319632107202

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis. Also from the value of r, there seems weak positive correlation between Attrition and Department.

# %% [markdown]
# **Correlation between Attrition and Distance from home.
# H0 = There is no significant correlation between Attrition and DistanceFromHome Ha = There is significant correlation between Attrition and DistanceFromHome**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.DistanceFromHome)
print(stats,p)
# Out:
# -0.00973014101017969 0.5182860428050771

# %% [markdown]
# As the p-value is greater than 0.05, we'll accept the null hypothesis.
# Also from the value of r, there seems weak negative correlation between Attrition and DitanceFromHome.

# %% [markdown]
# **Correlation between Attrition and Gender of employees.
# H0 = There is no significant correlation between Attrition and Gender,
# Ha = There is significant correlation between Attrition and Gender**

# %%
dataset["Gender"].replace(to_replace=("Female","Male"),value=(0,1),inplace=True)
dataset.head(5)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0       0  ...                 1.0      Y                11              8
# ...

# %%
stats,p = pearsonr(dataset.Attrition,dataset.Gender)
print(stats,p)
# Out:
# 0.018125078877010273 0.22881970951790567

# %% [markdown]
# As the p-value is greater than 0.05, we'll accept the null hypothesis. Also from the value of r, there seems weak positive correlation between Attrition and Gender.

# %% [markdown]
# **Correlation between Attrition and MonthlyIncome of employees.
# H0 = There is no significant correlation between Attrition and MonthlyIncome,
# Ha = There is significant correlation between Attrition and MonthlyIncome**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698115017 0.03842748490600132

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis.
# Also from the value of r, there seems weak negative correlation between Attrition and MonthlyIncome.

# %% [markdown]
# **Correlation between Attrition and PercentSalaryHike.
# H0 = There is no significant correlation between Attrition and PercentSalaryHike,
# Ha = There is significant correlation between Attrition and PercentSalaryHike**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.PercentSalaryHike)
print(stats,p)
# Out:
# 0.032532594891053514 0.030743386433355353

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis. Also from the value of r, there seems weak positive correlation between Attrition and PercentSalaryHike.

# %% [markdown]
# **Correlation between Attrition and YearsAtCompany.
# H0 = There is no significant correlation between Attrition and YearsAtCompany,
# Ha = There is significant correlation between Attrition and YearsAtCompany**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.YearsAtCompany)
print(stats,p)
# Out:
# -0.13439221398997714 3.1638831224877484e-19

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis. Also from the value of r, there seems weak negative correlation between Attrition and YearsAtCompany.

# %% [markdown]
# **Correlation between Attrition and Age.
# H0 = There is no significant correlation between Attrition and Age,
# Ha = There is significant correlation between Attrition and Age**

# %%
stats,p = pearsonr(dataset.Attrition,dataset.Age)
print(stats,p)
# Out:
# -0.15920500686577943 1.996801615887666e-26

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis. Also from the value of r, there seems weak negative correlation between Attrition and Age.

# %% [markdown]
# **Correlation between Attrition and TotalWorkingYears.
# H0 = There is no significant correlation between Attrition and TotalWorkingYears,
# Ha = There is significant correlation between Attrition and TotalWorkingYears**

# %%
dataset['TotalWorkingYears']=dataset['TotalWorkingYears'].fillna(11.28)

# %%
stats,p = pearsonr(dataset.Attrition,dataset.TotalWorkingYears)
print(stats,p)
# Out:
# -0.1701113635596517 5.473159751791005e-30

# %% [markdown]
# As the p-value is less than 0.05, we'll reject the null hypothesis. Also from the value of r, there seems weak negative correlation between Attrition and TotalWorkingYears.

# %% [markdown]
#  **Inference from aboove analysis**

# %% [markdown]
# From the correlation analysis, there seems to be a correlation of Attrition with following variables: Age, TotalWorkingYears,YearsAtCompany, PercentSalaryHike and MonthlyIncome. These variables are most important and are affecting the attrition in the company.
#
# Also fromt the statistical test we can say that,  There is no effect of DistanceFromHome variable on the attrition. So the variables that are need to be addressed riht away are Age, TotalWorkingYears,YearsAtCompany, PercentSalaryHike and MonthlyIncome.
